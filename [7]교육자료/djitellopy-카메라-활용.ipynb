# %% [markdown]
# <div style="background-color: #f9f9a9; padding: 1px; border-radius: 15px;color:blue;text-align:center;">
#   <h2>드론 카메라 활용</h2>
# </div>

# %% [markdown]
# ### 선수조건
# * 명령창에서 진행하여 주피터랩을 실행한다.
#   > mkdir 프로젝트명
#   > cd 프로젝트명
#   > py --list
#   > py -3.14 -m venv venv
#   > venv\Scripts\activate
#   > pip install djitellpy opencv-python jupyterlab
#   > jupyter lab --port=10888

# %%
# 필수 라이브러리 설치
# !pip install djitellopy opencv-python

# %%
# pip 최신버전 설치
# !python -m pip install --upgrade pip

# %% [markdown]
# # 목차
#
# ## 1. <a href="take_picture.ipynb" target=_blank>드론 카메라 활용: 사진찍기</a>
# ## 2. <a href="take-video.ipynb" target=_blank>드론 카메라 활용: 영상촬영</a>
